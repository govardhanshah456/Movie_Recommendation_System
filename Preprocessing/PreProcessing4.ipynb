# %% [markdown]
# <a href="https://colab.research.google.com/github/harsh9802/Movie_Recommendation_System/blob/main/Preprocessing/PreProcessing4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#changing current directory
# %cd /content/drive/MyDrive/Movie_Recommender
# Out:
# /content/drive/MyDrive/Movie_Recommender

# %%
#importing libraries
import numpy as np
import pandas as pd

# %%
#getting data of table using pd.read_html
#header=0 means ignoring first column of html table
url="https://en.wikipedia.org/wiki/List_of_American_films_of_2019"
df1=pd.read_html(url,header=0)[2]
df2=pd.read_html(url,header=0)[3]
df3=pd.read_html(url,header=0)[4]
df4=pd.read_html(url,header=0)[5]

# %%
#appending data to data frame
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)
df
# Out:
#       Opening  ...   Ref.
# 0     JANUARY  ...    [2]
# 1     JANUARY  ...    [3]
# 2     JANUARY  ...    [4]
# 3     JANUARY  ...    [5]
# 4     JANUARY  ...    [6]
# ..        ...  ...    ...
# 237  DECEMBER  ...  [132]
# 238  DECEMBER  ...  [221]
# 239  DECEMBER  ...  [222]
# 240  DECEMBER  ...  [223]
# 241  DECEMBER  ...  [224]
#
# [242 rows x 6 columns]

# %%
pip install tmdbv3api

# %%
#importing api and setting up details
from tmdbv3api import TMDb
import json
import requests
tmdb=TMDb()
#use your own key here
tmdb.api_key='04b9df5416d75be096abd805b24b47a1'

# %%
#searching for movie and getting genre of it using api
from tmdbv3api import Movie
tmdb_movie = Movie()
def get_genre(x):
    genres = []
    result = tmdb_movie.search(x)
    if result:
      movie_id=result[0].id
      response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
      data_json = response.json()
      if data_json['genres']:
          genre_str = " " 
          for i in range(0,len(data_json['genres'])):
              genres.append(data_json['genres'][i]['name'])
          return genre_str.join(genres)
      else:
          np.NaN

# %%
df['genres'] = df['Title'].map(lambda x: get_genre(str(x)))

# %%
df
# Out:
#       Opening  Opening.1  ...   Ref.                                    genres
# 0     JANUARY          4  ...    [2]                   Horror Thriller Mystery
# 1     JANUARY          4  ...    [3]                            Thriller Drama
# 2     JANUARY          4  ...    [4]                                  Thriller
# 3     JANUARY         11  ...    [5]                    Drama Adventure Family
# 4     JANUARY         11  ...    [6]                              Comedy Drama
# ..        ...        ...  ...    ...                                       ...
# 237  DECEMBER         25  ...  [132]  Animation Action Adventure Comedy Family
# 238  DECEMBER         25  ...  [221]                             Drama Romance
# 239  DECEMBER         25  ...  [222]                 War Drama Action Thriller
# 240  DECEMBER         25  ...  [223]                       Drama Crime History
# 241  DECEMBER         27  ...  [224]                                     Drama
#
# [242 rows x 7 columns]

# %%
#seperating columns that we need
df_2019 = df[['Title','Cast and crew','genres']]

# %%
df_2019
# Out:
#                  Title  ...                                    genres
# 0          Escape Room  ...                   Horror Thriller Mystery
# 1           Rust Creek  ...                            Thriller Drama
# 2     American Hangman  ...                                  Thriller
# 3     A Dog's Way Home  ...                    Drama Adventure Family
# 4           The Upside  ...                              Comedy Drama
# ..                 ...  ...                                       ...
# 237  Spies in Disguise  ...  Animation Action Adventure Comedy Family
# 238       Little Women  ...                             Drama Romance
# 239               1917  ...                 War Drama Action Thriller
# 240         Just Mercy  ...                       Drama Crime History
# 241           Clemency  ...                                     Drama
#
# [242 rows x 3 columns]

# %%
#getting director/directors
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2019['director_name'] = df_2019['Cast and crew'].map(lambda x: get_director(x))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
#getting actor
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2019['actor_1_name'] = df_2019['Cast and crew'].map(lambda x: get_actor1(x))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2019['actor_2_name'] = df_2019['Cast and crew'].map(lambda x: get_actor2(x))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2019['actor_3_name'] = df_2019['Cast and crew'].map(lambda x: get_actor3(x))

# %%
df_2019
# Out:
#                  Title  ...      actor_3_name
# 0          Escape Room  ...  Deborah Ann Woll
# 1           Rust Creek  ...      Sean O'Bryan
# 2     American Hangman  ...     Oliver Dennis
# 3     A Dog's Way Home  ...   Alexandra Shipp
# 4           The Upside  ...     Nicole Kidman
# ..                 ...  ...               ...
# 237  Spies in Disguise  ...     Rashida Jones
# 238       Little Women  ...     Florence Pugh
# 239               1917  ...       Mark Strong
# 240         Just Mercy  ...       Brie Larson
# 241           Clemency  ...       Aldis Hodge
#
# [242 rows x 7 columns]

# %%
#rename columns
df_2019 = df_2019.rename(columns={'Title':'movie_title'})

# %%
#split out useful columns
new_df19 = df_2019.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df19
# Out:
#               director_name  ...        movie_title
# 0              Adam Robitel  ...        Escape Room
# 1               Jen McGowan  ...         Rust Creek
# 2         Wilson Coneybeare  ...   American Hangman
# 3      Charles Martin Smith  ...   A Dog's Way Home
# 4               Neil Burger  ...         The Upside
# ..                      ...  ...                ...
# 237  Nick Bruno, Troy Quane  ...  Spies in Disguise
# 238            Greta Gerwig  ...       Little Women
# 239              Sam Mendes  ...               1917
# 240   Destin Daniel Cretton  ...         Just Mercy
# 241         Chinonye Chukwu  ...           Clemency
#
# [242 rows x 6 columns]

# %%
#replace nan values 
new_df19['actor_1_name'] = new_df19['actor_1_name'].replace(np.nan, 'unknown')
new_df19['actor_2_name'] = new_df19['actor_2_name'].replace(np.nan, 'unknown')
new_df19['actor_3_name'] = new_df19['actor_3_name'].replace(np.nan, 'unknown')

# %%
#lower caseing title
new_df19['movie_title'] = new_df19['movie_title'].str.lower()

# %%
new_df19['comb'] = new_df19['actor_1_name'] + ' ' + new_df19['actor_2_name'] + ' '+ new_df19['actor_3_name'] + ' '+ new_df19['director_name'] +' ' + new_df19['genres']

# %%
new_df19
# Out:
#               director_name  ...                                               comb
# 0              Adam Robitel  ...  Taylor Russell Logan Miller Deborah Ann Woll A...
# 1               Jen McGowan  ...  Hermione Corfield Jay Paulson Sean O'Bryan Jen...
# 2         Wilson Coneybeare  ...  Donald Sutherland Vincent Kartheiser Oliver De...
# 3      Charles Martin Smith  ...  Bryce Dallas Howard Edward James Olmos Alexand...
# 4               Neil Burger  ...  Bryan Cranston Kevin Hart Nicole Kidman Neil B...
# ..                      ...  ...                                                ...
# 237  Nick Bruno, Troy Quane  ...  Will Smith Tom Holland Rashida Jones Nick Brun...
# 238            Greta Gerwig  ...  Saoirse Ronan Emma Watson Florence Pugh Greta ...
# 239              Sam Mendes  ...  George MacKay Dean-Charles Chapman Mark Strong...
# 240   Destin Daniel Cretton  ...  Michael B. Jordan Jamie Foxx Brie Larson Desti...
# ...

# %%
#reading old dataset
old_df = pd.read_csv('2018_Movie_data.csv')

# %%
old_df
# Out:
#        director_name  ...                                               comb
# 0        Doug Walker  ...  Doug Walker Rob Walker unknown Doug Walker Doc...
# 1      Rob Letterman  ...  Amy Poehler Rainn Wilson Stephen Colbert Rob L...
# 2      George Miller  ...  Robin Williams Brad Pitt Common George Miller ...
# 3            unknown  ...  Don Johnson Philip Michael Thomas John Diehl u...
# 4       Chris Miller  ...  Salma Hayek Constance Marie Amy Sedaris Chris ...
# ...              ...  ...                                                ...
# 37092     Etan Cohen  ...  Will Ferrell John C. Reilly Rebecca Hall Etan ...
# 37093     Adam McKay  ...  Christian Bale Amy Adams Steve Carell Adam McK...
# 37094     Mimi Leder  ...  Felicity Jones Armie Hammer Justin Theroux Mim...
# 37095   Karyn Kusama  ...  Nicole Kidman Sebastian Stan Toby Kebbell Kary...
# 37096    David Slade  ...  Fionn Whitehead Will Poulter Asim Chaudhry Dav...
#
# [37097 rows x 7 columns]

# %%
#appending combined dataset of 2019 to old dataset
new_df=old_df.append(new_df19,ignore_index=True)

# %%
new_df
# Out:
#                 director_name  ...                                               comb
# 0                 Doug Walker  ...  Doug Walker Rob Walker unknown Doug Walker Doc...
# 1               Rob Letterman  ...  Amy Poehler Rainn Wilson Stephen Colbert Rob L...
# 2               George Miller  ...  Robin Williams Brad Pitt Common George Miller ...
# 3                     unknown  ...  Don Johnson Philip Michael Thomas John Diehl u...
# 4                Chris Miller  ...  Salma Hayek Constance Marie Amy Sedaris Chris ...
# ...                       ...  ...                                                ...
# 37334  Nick Bruno, Troy Quane  ...  Will Smith Tom Holland Rashida Jones Nick Brun...
# 37335            Greta Gerwig  ...  Saoirse Ronan Emma Watson Florence Pugh Greta ...
# 37336              Sam Mendes  ...  George MacKay Dean-Charles Chapman Mark Strong...
# 37337   Destin Daniel Cretton  ...  Michael B. Jordan Jamie Foxx Brie Larson Desti...
# ...

# %%
#checking nan values 
new_df.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# comb             0
# dtype: int64

# %%
new_df.drop_duplicates(subset ="movie_title", keep = 'last', inplace = True)

# %%
new_df
# Out:
#                 director_name  ...                                               comb
# 0                 Doug Walker  ...  Doug Walker Rob Walker unknown Doug Walker Doc...
# 1               Rob Letterman  ...  Amy Poehler Rainn Wilson Stephen Colbert Rob L...
# 2               George Miller  ...  Robin Williams Brad Pitt Common George Miller ...
# 3                     unknown  ...  Don Johnson Philip Michael Thomas John Diehl u...
# 4                Chris Miller  ...  Salma Hayek Constance Marie Amy Sedaris Chris ...
# ...                       ...  ...                                                ...
# 37334  Nick Bruno, Troy Quane  ...  Will Smith Tom Holland Rashida Jones Nick Brun...
# 37335            Greta Gerwig  ...  Saoirse Ronan Emma Watson Florence Pugh Greta ...
# 37336              Sam Mendes  ...  George MacKay Dean-Charles Chapman Mark Strong...
# 37337   Destin Daniel Cretton  ...  Michael B. Jordan Jamie Foxx Brie Larson Desti...
# ...

# %%
#getting new dataset having all 2018 movies
new_df.to_csv('2019_Movie_data.csv',index=False)
