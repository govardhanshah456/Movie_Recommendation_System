# %% [markdown]
# <a href="https://colab.research.google.com/github/harsh9802/Movie_Recommendation_System/blob/main/Preprocessing/PreProcessing2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#changing current directory
# %cd /content/drive/MyDrive/Movie_Recommender
# Out:
# /content/drive/MyDrive/Movie_Recommender

# %%
#verifying if it is changed
# !pwd
# Out:
# /content/drive/MyDrive/Movie_Recommender

# %%
#import libraries
import numpy as np
import pandas as pd

# %%
#importing another dataset
credits=pd.read_csv('credits[1].csv')
credits.head(5)
# Out:
#                                                 cast  ...     id
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...  ...    862
# 1  [{'cast_id': 1, 'character': 'Alan Parrish', '...  ...   8844
# 2  [{'cast_id': 2, 'character': 'Max Goldman', 'c...  ...  15602
# 3  [{'cast_id': 1, 'character': "Savannah 'Vannah...  ...  31357
# 4  [{'cast_id': 1, 'character': 'George Banks', '...  ...  11862
#
# [5 rows x 3 columns]

# %%
metadata=pd.read_csv('movies_metadata[1].csv')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
#converting release date to date month year format so that we can sort out 2017 movies
metadata['release_date'] = pd.to_datetime(metadata['release_date'], errors='coerce')

# %%
metadata['year'] = metadata['release_date'].dt.year

# %%
metadata['year'].value_counts().sort_index()
# Out:
# 1874.0       1
# 1878.0       1
# 1883.0       1
# 1887.0       1
# 1888.0       2
#           ...
# 2015.0    1905
# 2016.0    1604
# 2017.0     532
# 2018.0       5
# 2020.0       1
# Name: year, Length: 135, dtype: int64

# %%
#getting 2017 movies
new_metadata = metadata.loc[metadata.year <= 2017,['genres','id','title','year']]
new_metadata
# Out:
#                                                   genres  ...    year
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...  ...  1995.0
# 1      [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...  ...  1995.0
# 2      [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...  ...  1995.0
# 3      [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...  ...  1995.0
# 4                         [{'id': 35, 'name': 'Comedy'}]  ...  1995.0
# ...                                                  ...  ...     ...
# 45460  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...  ...  1991.0
# 45462                      [{'id': 18, 'name': 'Drama'}]  ...  2011.0
# 45463  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...  ...  2003.0
# 45464                                                 []  ...  1917.0
# 45465                                                 []  ...  2017.0
#
# [45370 rows x 4 columns]

# %%
type(new_metadata['id'])
# Out:
# pandas.core.series.Series

# %%
#converting id type to integer
new_metadata['id']=new_metadata['id'].astype(int)

# %%
#merging two dataset
data=pd.merge(new_metadata,credits,on='id')

# %%
#converting object type to list
import ast
data['genres'] = data['genres'].map(lambda x: ast.literal_eval(x))
data['cast'] = data['cast'].map(lambda x: ast.literal_eval(x))
data['crew'] = data['crew'].map(lambda x: ast.literal_eval(x))

# %%
#space seperating the genres that are in list and first adding them to a list funtion
def make_genre_list(x):
  genre=[]
  s=" "
  for i in x:
    if i.get('name')=='Science Fiction':
      scifi='Sci-fi'
      genre.append(scifi)
    else:
      genre.append(i.get('name'))
  if genre==[]:
    return np.NaN
  else:
    return s.join(genre)

# %%
data['genres_list']=data['genres'].map(lambda x:make_genre_list(x))

# %%
data['genres_list'].head(5)
# Out:
# 0     Animation Comedy Family
# 1    Adventure Fantasy Family
# 2              Romance Comedy
# 3        Comedy Drama Romance
# 4                      Comedy
# Name: genres_list, dtype: object

# %%
#making actor list and seperating it as actor1 actor2 actor3(as our initial dataset has this format)
def get_actor1(x):
  actor1=[]
  s=" "
  for i in x:
    actor1.append(i.get('name'))
  if actor1 == []:
   return np.NaN
  else:
   return (actor1[0])

# %%
data['actor_1_name']=data['cast'].map(lambda x:get_actor1(x))
data['actor_1_name']
# Out:
# 0               Tom Hanks
# 1          Robin Williams
# 2          Walter Matthau
# 3         Whitney Houston
# 4            Steve Martin
#                ...
# 45440      Patrick Bergin
# 45441        Angel Aquino
# 45442       Erika Eleniak
# 45443    Iwan Mosschuchin
# 45444                 NaN
# Name: actor_1_name, Length: 45445, dtype: object

# %%
def get_actor2(x):
  actor1=[]
  s=" "
  for i in x:
    actor1.append(i.get('name'))
  if actor1 == [] or len(actor1)<=1:
   return np.NaN
  else:
   return (actor1[1])

# %%
data['actor_2_name'] = data['cast'].map(lambda x: get_actor2(x))

# %%
def get_actor3(x):
    actor1 = []
    for i in x:
        actor1.append(i.get('name'))
    if actor1 == [] or len(actor1)<=2:
        return np.NaN
    else:
        return (actor1[2])

# %%
data['actor_3_name'] = data['cast'].map(lambda x: get_actor3(x))

# %%
#now doing for director
def get_directors(x):
    dt = []
    st = " "
    for i in x:
        if i.get('job') == 'Director':
            dt.append(i.get('name'))
    if dt == []:
        return np.NaN
    else:
        return (st.join(dt))

# %%
data['director_name'] = data['crew'].map(lambda x: get_directors(x))

# %%
#extracting working columns
movie = data.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres_list','title']]
movie
# Out:
#           director_name  ...                        title
# 0         John Lasseter  ...                    Toy Story
# 1          Joe Johnston  ...                      Jumanji
# 2         Howard Deutch  ...             Grumpier Old Men
# 3       Forest Whitaker  ...            Waiting to Exhale
# 4         Charles Shyer  ...  Father of the Bride Part II
# ...                 ...  ...                          ...
# 45440        John Irvin  ...                   Robin Hood
# 45441          Lav Diaz  ...          Century of Birthing
# 45442    Mark L. Lester  ...                     Betrayal
# 45443  Yakov Protazanov  ...             Satan Triumphant
# 45444     Daisy Asquith  ...                     Queerama
#
# [45445 rows x 6 columns]

# %%
#remove nan values columns
movie.isna().sum()
movie = movie.dropna(how='any')
movie.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres_list      0
# title            0
# dtype: int64

# %%
#renaming columns to the ones which are in the data.csv file
movie = movie.rename(columns={'genres_list':'genres'})
movie = movie.rename(columns={'title':'movie_title'})

# %%
#making title lower case as in data.csv file it is that way
movie['movie_title'] = movie['movie_title'].str.lower()

# %%
#making new column which has concatination of actor names director names genres 
movie['comb'] = movie['actor_1_name'] + ' ' + movie['actor_2_name'] + ' '+ movie['actor_3_name'] + ' '+ movie['director_name'] +' ' + movie['genres']

# %%
movie
# Out:
#          director_name  ...                                               comb
# 0        John Lasseter  ...  Tom Hanks Tim Allen Don Rickles John Lasseter ...
# 1         Joe Johnston  ...  Robin Williams Jonathan Hyde Kirsten Dunst Joe...
# 2        Howard Deutch  ...  Walter Matthau Jack Lemmon Ann-Margret Howard ...
# 3      Forest Whitaker  ...  Whitney Houston Angela Bassett Loretta Devine ...
# 4        Charles Shyer  ...  Steve Martin Diane Keaton Martin Short Charles...
# ...                ...  ...                                                ...
# 45438         Ben Rock  ...  Monty Bane Lucy Butler David Grammer Ben Rock ...
# 45439    Aaron Osborne  ...  Lisa Boyle Kena Land Zaneta Polard Aaron Osbor...
# 45440       John Irvin  ...  Patrick Bergin Uma Thurman David Morrissey Joh...
# 45441         Lav Diaz  ...  Angel Aquino Perry Dizon Hazel Orencio Lav Dia...
# 45442   Mark L. Lester  ...  Erika Eleniak Adam Baldwin Julie du Page Mark ...
#
# ...

# %%
#now we need to make a new data file for 2017 movies so we read old data file
old = pd.read_csv('data.csv')

# %%
old
# Out:
#           director_name  ...                                        movie_title
# 0         James Cameron  ...                                             avatar
# 1        Gore Verbinski  ...           pirates of the caribbean: at world's end
# 2            Sam Mendes  ...                                            spectre
# 3     Christopher Nolan  ...                              the dark knight rises
# 4           Doug Walker  ...  star wars: episode vii - the force awakens    ...
# ...                 ...  ...                                                ...
# 5038        Scott Smith  ...                            signed sealed delivered
# 5039            unknown  ...                          the following
# 5040   Benjamin Roberds  ...                               a plague so pleasant
# 5041        Daniel Hsia  ...                                   shanghai calling
# 5042           Jon Gunn  ...                                  my date with drew
#
# [5043 rows x 6 columns]

# %%
#we do the same combinaton column thing here
old['comb'] = old['actor_1_name'] + ' ' + old['actor_2_name'] + ' '+ old['actor_3_name'] + ' '+ old['director_name'] +' ' + old['genres']

# %%
old
# Out:
#           director_name  ...                                               comb
# 0         James Cameron  ...  CCH Pounder Joel David Moore Wes Studi James C...
# 1        Gore Verbinski  ...  Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2            Sam Mendes  ...  Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3     Christopher Nolan  ...  Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4           Doug Walker  ...  Doug Walker Rob Walker unknown Doug Walker Doc...
# ...                 ...  ...                                                ...
# 5038        Scott Smith  ...  Eric Mabius Daphne Zuniga Crystal Lowe Scott S...
# 5039            unknown  ...  Natalie Zea Valorie Curry Sam Underwood unknow...
# 5040   Benjamin Roberds  ...  Eva Boehnke Maxwell Moody David Chandler Benja...
# 5041        Daniel Hsia  ...  Alan Ruck Daniel Henney Eliza Coupe Daniel Hsi...
# 5042           Jon Gunn  ...  John August Brian Herzlinger Jon Gunn Jon Gunn...
#
# ...

# %%
#now we make a new append new data to old file 
new = old.append(movie)

# %%
new
# Out:
#            director_name  ...                                               comb
# 0          James Cameron  ...  CCH Pounder Joel David Moore Wes Studi James C...
# 1         Gore Verbinski  ...  Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2             Sam Mendes  ...  Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3      Christopher Nolan  ...  Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4            Doug Walker  ...  Doug Walker Rob Walker unknown Doug Walker Doc...
# ...                  ...  ...                                                ...
# 45438           Ben Rock  ...  Monty Bane Lucy Butler David Grammer Ben Rock ...
# 45439      Aaron Osborne  ...  Lisa Boyle Kena Land Zaneta Polard Aaron Osbor...
# 45440         John Irvin  ...  Patrick Bergin Uma Thurman David Morrissey Joh...
# 45441           Lav Diaz  ...  Angel Aquino Perry Dizon Hazel Orencio Lav Dia...
# 45442     Mark L. Lester  ...  Erika Eleniak Adam Baldwin Julie du Page Mark ...
#
# ...

# %%
#we remove duplicates if any
new.drop_duplicates(subset ="movie_title", keep = 'last', inplace = True)

# %%
new
# Out:
#         director_name  ...                                               comb
# 4         Doug Walker  ...  Doug Walker Rob Walker unknown Doug Walker Doc...
# 68      Rob Letterman  ...  Amy Poehler Rainn Wilson Stephen Colbert Rob L...
# 175     George Miller  ...  Robin Williams Brad Pitt Common George Miller ...
# 177           unknown  ...  Don Johnson Philip Michael Thomas John Diehl u...
# 191      Chris Miller  ...  Salma Hayek Constance Marie Amy Sedaris Chris ...
# ...               ...  ...                                                ...
# 45438        Ben Rock  ...  Monty Bane Lucy Butler David Grammer Ben Rock ...
# 45439   Aaron Osborne  ...  Lisa Boyle Kena Land Zaneta Polard Aaron Osbor...
# 45440      John Irvin  ...  Patrick Bergin Uma Thurman David Morrissey Joh...
# 45441        Lav Diaz  ...  Angel Aquino Perry Dizon Hazel Orencio Lav Dia...
# 45442  Mark L. Lester  ...  Erika Eleniak Adam Baldwin Julie du Page Mark ...
#
# [36827 rows x 7 columns]

# %%
#we import that to csv file 
new.to_csv('new_data.csv',index=False)
