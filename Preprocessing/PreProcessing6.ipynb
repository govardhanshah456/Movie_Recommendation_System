# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#changing current directory
# %cd /content/drive/MyDrive/Movie_Recommender
# Out:
# /content/drive/MyDrive/Movie_Recommender

# %%
#importing libraries
import numpy as np
import pandas as pd

# %%
#getting data of table using pd.read_html
#header=0 means ignoring first column of html table
url="https://en.wikipedia.org/wiki/List_of_American_films_of_2021"
df1=pd.read_html(url,header=0)[2]
df2=pd.read_html(url,header=0)[3]
df3=pd.read_html(url,header=0)[4]
df4=pd.read_html(url,header=0)[5]

# %%
#appending data to data frame
df = df2.append(df3.append(df4,ignore_index=True),ignore_index=True)
df
# Out:
#        Opening  ...   Ref.
# 0      JANUARY  ...    NaN
# 1      JANUARY  ...    NaN
# 2      JANUARY  ...    NaN
# 3      JANUARY  ...    NaN
# 4      JANUARY  ...    NaN
# ..         ...  ...    ...
# 258  SEPTEMBER  ...  [195]
# 259  SEPTEMBER  ...  [196]
# 260  SEPTEMBER  ...  [167]
# 261  SEPTEMBER  ...  [197]
# 262  SEPTEMBER  ...  [198]
#
# [263 rows x 7 columns]

# %%
pip install tmdbv3api

# %%
#importing api and setting up details
from tmdbv3api import TMDb
import json
import requests
tmdb=TMDb()
#use your own key here
tmdb.api_key='04b9df5416d75be096abd805b24b47a1'

# %%
#searching for movie and getting genre of it using api
from tmdbv3api import Movie
tmdb_movie = Movie()
def get_genre(x):
    genres = []
    result = tmdb_movie.search(x)
    if result:
      movie_id=result[0].id
      response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
      data_json = response.json()
      if data_json['genres']:
          genre_str = " " 
          for i in range(0,len(data_json['genres'])):
              genres.append(data_json['genres'][i]['name'])
          return genre_str.join(genres)
      else:
          np.NaN

# %%
df['genres'] = df['Title'].map(lambda x: get_genre(str(x)))

# %%
df
# Out:
#        Opening  ...                                           genres
# 0      JANUARY  ...                                Horror Action War
# 1      JANUARY  ...                                            Drama
# 2      JANUARY  ...                               Comedy Crime Drama
# 3      JANUARY  ...                                    Drama History
# 4      JANUARY  ...                  Thriller Action Science Fiction
# ..         ...  ...                                              ...
# 258  SEPTEMBER  ...  Animation Family Fantasy Comedy Music Adventure
# 259  SEPTEMBER  ...                                            Drama
# 260  SEPTEMBER  ...                                   Drama Thriller
# 261  SEPTEMBER  ...                                            Drama
# 262  SEPTEMBER  ...                                    Romance Drama
#
# [263 rows x 8 columns]

# %%
#seperating columns that we need
df_2021 = df[['Title','Cast and crew','genres']]

# %%
df_2021
# Out:
#                                 Title  ...                                           genres
# 0                 Shadow in the Cloud  ...                                Horror Action War
# 1                     The White Tiger  ...                                            Drama
# 2                         Locked Down  ...                               Comedy Crime Drama
# 3                             The Dig  ...                                    Drama History
# 4                    Outside the Wire  ...                  Thriller Action Science Fiction
# ..                                ...  ...                                              ...
# 258  My Little Pony: A New Generation  ...  Animation Family Fantasy Comedy Music Adventure
# 259                  Dear Evan Hansen  ...                                            Drama
# 260                        The Guilty  ...                                   Drama Thriller
# ...

# %%
#getting director/directors
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2021['director_name'] = df_2021['Cast and crew'].map(lambda x: get_director(x))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
#getting actor
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2021['actor_1_name'] = df_2021['Cast and crew'].map(lambda x: get_actor1(x))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2021['actor_2_name'] = df_2021['Cast and crew'].map(lambda x: get_actor2(x))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2021['actor_3_name'] = df_2021['Cast and crew'].map(lambda x: get_actor3(x))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_2021
# Out:
#                                 Title  ...           actor_3_name
# 0                 Shadow in the Cloud  ...           Beulah Koale
# 1                     The White Tiger  ...  Priyanka Chopra Jonas
# 2                         Locked Down  ...       Stephen Merchant
# 3                             The Dig  ...             Lily James
# 4                    Outside the Wire  ...          Emily Beecham
# ..                                ...  ...                    ...
# 258  My Little Pony: A New Generation  ...          James Marsden
# 259                  Dear Evan Hansen  ...       Amandla Stenberg
# 260                        The Guilty  ...           Riley Keough
# 261                 Birds of Paradise  ...      Jacqueline Bisset
# 262                     After We Fell  ...         Louise Lombard
#
# [263 rows x 7 columns]

# %%
df_2021 = df_2021.rename(columns={'Title':'movie_title'})

# %%
#split out useful columns
new_df21 = df_2021.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df21
# Out:
#                 director_name  ...                       movie_title
# 0              Roseanne Liang  ...               Shadow in the Cloud
# 1               Ramin Bahrani  ...                   The White Tiger
# 2                  Doug Liman  ...                       Locked Down
# 3                 Simon Stone  ...                           The Dig
# 4             Mikael Håfström  ...                  Outside the Wire
# ..                        ...  ...                               ...
# 258  Robert Cullen, Jose Ucha  ...  My Little Pony: A New Generation
# 259           Stephen Chbosky  ...                  Dear Evan Hansen
# 260             Antoine Fuqua  ...                        The Guilty
# 261         Sarah Adina Smith  ...                 Birds of Paradise
# 262           Castille Landon  ...                     After We Fell
#
# [263 rows x 6 columns]

# %%
#replace nan values 
new_df21['actor_1_name'] = new_df21['actor_1_name'].replace(np.nan, 'unknown')
new_df21['actor_2_name'] = new_df21['actor_2_name'].replace(np.nan, 'unknown')
new_df21['actor_3_name'] = new_df21['actor_3_name'].replace(np.nan, 'unknown')

# %%
new_df21['movie_title'] = new_df21['movie_title'].str.lower()

# %%
new_df21['comb'] = new_df21['actor_1_name'] + ' ' + new_df21['actor_2_name'] + ' '+ new_df21['actor_3_name'] + ' '+ new_df21['director_name'] +' ' + new_df21['genres']

# %%
new_df21
# Out:
#                 director_name  ...                                               comb
# 0              Roseanne Liang  ...  Chloë Grace Moretz Taylor John Smith Beulah Ko...
# 1               Ramin Bahrani  ...  Adarsh Gourav Rajkummar Rao Priyanka Chopra Jo...
# 2                  Doug Liman  ...  Anne Hathaway Chiwetel Ejiofor Stephen Merchan...
# 3                 Simon Stone  ...  Carey Mulligan Ralph Fiennes Lily James Simon ...
# 4             Mikael Håfström  ...  Anthony Mackie Damson Idris Emily Beecham Mika...
# ..                        ...  ...                                                ...
# 258  Robert Cullen, Jose Ucha  ...  Vanessa Hudgens Kimiko Glenn James Marsden Rob...
# 259           Stephen Chbosky  ...  Ben Platt Kaitlyn Dever Amandla Stenberg Steph...
# 260             Antoine Fuqua  ...  Jake Gyllenhaal Ethan Hawke Riley Keough Antoi...
# 261         Sarah Adina Smith  ...  Kristine Froseth Diana Silvers Jacqueline Biss...
# ...

# %%
#reading old dataset
old_df = pd.read_csv('2020_Movie_data.csv')

# %%
old_df
# Out:
#           director_name  ...                                               comb
# 0         James Cameron  ...  CCH Pounder Joel David Moore Wes Studi James C...
# 1        Gore Verbinski  ...  Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2            Sam Mendes  ...  Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3     Christopher Nolan  ...  Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4           Doug Walker  ...  Doug Walker Rob Walker unknown Doug Walker Doc...
# ...                 ...  ...                                                ...
# 6144   Robert Rodriguez  ...  Priyanka Chopra Jonas Pedro Pascal YaYa Gossel...
# 6145    Paul Greengrass  ...  Tom Hanks Helena Zengel unknown Paul Greengras...
# 6146        Regina King  ...  Kingsley Ben-Adir Eli Goree Aldis Hodge Regina...
# 6147    Emerald Fennell  ...  Carey Mulligan Bo Burnham Alison Brie Emerald ...
# 6148   Kornél Mundruczó  ...  Vanessa Kirby Shia LaBeouf Molly Parker Kornél...
#
# ...

# %%
#appending combined dataset of 2019 to old dataset
new_df=old_df.append(new_df21,ignore_index=True)

# %%
new_df
# Out:
#                  director_name  ...                                               comb
# 0                James Cameron  ...  CCH Pounder Joel David Moore Wes Studi James C...
# 1               Gore Verbinski  ...  Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2                   Sam Mendes  ...  Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3            Christopher Nolan  ...  Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4                  Doug Walker  ...  Doug Walker Rob Walker unknown Doug Walker Doc...
# ...                        ...  ...                                                ...
# 6407  Robert Cullen, Jose Ucha  ...  Vanessa Hudgens Kimiko Glenn James Marsden Rob...
# 6408           Stephen Chbosky  ...  Ben Platt Kaitlyn Dever Amandla Stenberg Steph...
# 6409             Antoine Fuqua  ...  Jake Gyllenhaal Ethan Hawke Riley Keough Antoi...
# 6410         Sarah Adina Smith  ...  Kristine Froseth Diana Silvers Jacqueline Biss...
# ...

# %%
new_df.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           1
# movie_title      0
# comb             1
# dtype: int64

# %%
new_df=new_df.dropna(how='any')

# %%
new_df.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# comb             0
# dtype: int64

# %%
new_df.to_csv('final_dataset.csv',index=False)
