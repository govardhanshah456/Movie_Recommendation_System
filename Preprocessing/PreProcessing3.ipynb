# %% [markdown]
# <a href="https://colab.research.google.com/github/harsh9802/Movie_Recommendation_System/blob/main/Preprocessing/PreProcessing3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#changing current directory
# %cd /content/drive/MyDrive/Movie_Recommender
# Out:
# /content/drive/MyDrive/Movie_Recommender

# %%
#importing libraries
import numpy as np
import pandas as pd

# %%
#getting data of table using pd.read_html
url="https://en.wikipedia.org/wiki/List_of_American_films_of_2018"
df1=pd.read_html(url,header=0)[2]
df2=pd.read_html(url,header=0)[3]
df3=pd.read_html(url,header=0)[4]
df4=pd.read_html(url,header=0)[5]

# %%
#appending data to data frame
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)
df
# Out:
#       Opening  ...   Ref.
# 0     JANUARY  ...    NaN
# 1     JANUARY  ...    NaN
# 2     JANUARY  ...    NaN
# 3     JANUARY  ...    NaN
# 4     JANUARY  ...    NaN
# ..        ...  ...    ...
# 267  DECEMBER  ...  [164]
# 268  DECEMBER  ...  [137]
# 269  DECEMBER  ...  [228]
# 270  DECEMBER  ...  [260]
# 271  DECEMBER  ...  [261]
#
# [272 rows x 7 columns]

# %%
pip install tmdbv3api

# %%
#importing api and setting up details
from tmdbv3api import TMDb
import json
import requests
tmdb=TMDb()
#use your own key here
tmdb.api_key='04b9df5416d75be096abd805b24b47a1'

# %%
#searching for movie and getting genre of it using api
from tmdbv3api import Movie
tmdb_movie = Movie()
def get_genre(x):
    genres = []
    result = tmdb_movie.search(x)
    if result:
      movie_id=result[0].id
      response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
      data_json = response.json()
      if data_json['genres']:
          genre_str = " " 
          for i in range(0,len(data_json['genres'])):
              genres.append(data_json['genres'][i]['name'])
          return genre_str.join(genres)
      else:
          np.NaN

# %%
df['genres'] = df['Title'].map(lambda x: get_genre(str(x)))

# %%
df
# Out:
#       Opening  ...                                           genres
# 0     JANUARY  ...                          Horror Mystery Thriller
# 1     JANUARY  ...                                   Thriller Drama
# 2     JANUARY  ...                                  Action Thriller
# 3     JANUARY  ...                            Drama History Western
# 4     JANUARY  ...                                  Action Thriller
# ..        ...  ...                                              ...
# 267  DECEMBER  ...                   Mystery Adventure Comedy Crime
# 268  DECEMBER  ...        Thriller Science Fiction Action Adventure
# 269  DECEMBER  ...                                    Drama History
# 270  DECEMBER  ...                      Thriller Crime Drama Action
# 271  DECEMBER  ...  Science Fiction Mystery Drama Thriller TV Movie
#
# [272 rows x 8 columns]

# %%
#seperating columns that we need
df_2018 = df[['Title','Cast and crew','genres']]

# %%
df_2018
# Out:
#                           Title  ...                                           genres
# 0       Insidious: The Last Key  ...                          Horror Mystery Thriller
# 1              The Strange Ones  ...                                   Thriller Drama
# 2                      Stratton  ...                                  Action Thriller
# 3                 Sweet Country  ...                            Drama History Western
# 4                  The Commuter  ...                                  Action Thriller
# ..                          ...  ...                                              ...
# 267             Holmes & Watson  ...                   Mystery Adventure Comedy Crime
# 268                        Vice  ...        Thriller Science Fiction Action Adventure
# 269         On the Basis of Sex  ...                                    Drama History
# 270                   Destroyer  ...                      Thriller Crime Drama Action
# ...

# %%
#getting director/directors
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2018['director_name'] = df_2018['Cast and crew'].map(lambda x: get_director(x))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
#getting actor
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2018['actor_1_name'] = df_2018['Cast and crew'].map(lambda x: get_actor1(x))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2018['actor_2_name'] = df_2018['Cast and crew'].map(lambda x: get_actor2(x))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2018['actor_3_name'] = df_2018['Cast and crew'].map(lambda x: get_actor3(x))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_2018
# Out:
#                           Title  ...    actor_3_name
# 0       Insidious: The Last Key  ...  Leigh Whannell
# 1              The Strange Ones  ...   Emily Althaus
# 2                      Stratton  ...      Gemma Chan
# 3                 Sweet Country  ...             NaN
# 4                  The Commuter  ...  Patrick Wilson
# ..                          ...  ...             ...
# 267             Holmes & Watson  ...    Rebecca Hall
# 268                        Vice  ...    Steve Carell
# 269         On the Basis of Sex  ...  Justin Theroux
# 270                   Destroyer  ...    Toby Kebbell
# 271  Black Mirror: Bandersnatch  ...   Asim Chaudhry
#
# [272 rows x 7 columns]

# %%
#rename columns
df_2018 = df_2018.rename(columns={'Title':'movie_title'})

# %%
#split out useful columns
new_df18 = df_2018.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df18.head(5)
# Out:
#         director_name  ...              movie_title
# 0        Adam Robitel  ...  Insidious: The Last Key
# 1    Lauren Wolkstein  ...         The Strange Ones
# 2          Simon West  ...                 Stratton
# 3    Warwick Thornton  ...            Sweet Country
# 4  Jaume Collet-Serra  ...             The Commuter
#
# [5 rows x 6 columns]

# %%
#replace nan values 
new_df18['actor_1_name'] = new_df18['actor_1_name'].replace(np.nan, 'unknown')
new_df18['actor_2_name'] = new_df18['actor_2_name'].replace(np.nan, 'unknown')
new_df18['actor_3_name'] = new_df18['actor_3_name'].replace(np.nan, 'unknown')

# %%
#lower caseing title
new_df18['movie_title'] = new_df18['movie_title'].str.lower()

# %%
#combining all required fields to one field
new_df18['comb'] = new_df18['actor_1_name'] + ' ' + new_df18['actor_2_name'] + ' '+ new_df18['actor_3_name'] + ' '+ new_df18['director_name'] +' ' + new_df18['genres']

# %%
new_df18
# Out:
#           director_name  ...                                               comb
# 0          Adam Robitel  ...  Lin Shaye Angus Sampson Leigh Whannell Adam Ro...
# 1      Lauren Wolkstein  ...  Alex Pettyfer James Freedson-Jackson Emily Alt...
# 2            Simon West  ...  Dominic Cooper Austin Stowell Gemma Chan Simon...
# 3      Warwick Thornton  ...  Bryan Brown Sam Neill unknown Warwick Thornton...
# 4    Jaume Collet-Serra  ...  Liam Neeson Vera Farmiga Patrick Wilson Jaume ...
# ..                  ...  ...                                                ...
# 267          Etan Cohen  ...  Will Ferrell John C. Reilly Rebecca Hall Etan ...
# 268          Adam McKay  ...  Christian Bale Amy Adams Steve Carell Adam McK...
# 269          Mimi Leder  ...  Felicity Jones Armie Hammer Justin Theroux Mim...
# 270        Karyn Kusama  ...  Nicole Kidman Sebastian Stan Toby Kebbell Kary...
# 271         David Slade  ...  Fionn Whitehead Will Poulter Asim Chaudhry Dav...
#
# ...

# %%
#reading old dataset
old_df = pd.read_csv('new_data.csv')

# %%
old_df
# Out:
#         director_name  ...                                               comb
# 0         Doug Walker  ...  Doug Walker Rob Walker unknown Doug Walker Doc...
# 1       Rob Letterman  ...  Amy Poehler Rainn Wilson Stephen Colbert Rob L...
# 2       George Miller  ...  Robin Williams Brad Pitt Common George Miller ...
# 3             unknown  ...  Don Johnson Philip Michael Thomas John Diehl u...
# 4        Chris Miller  ...  Salma Hayek Constance Marie Amy Sedaris Chris ...
# ...               ...  ...                                                ...
# 36822        Ben Rock  ...  Monty Bane Lucy Butler David Grammer Ben Rock ...
# 36823   Aaron Osborne  ...  Lisa Boyle Kena Land Zaneta Polard Aaron Osbor...
# 36824      John Irvin  ...  Patrick Bergin Uma Thurman David Morrissey Joh...
# 36825        Lav Diaz  ...  Angel Aquino Perry Dizon Hazel Orencio Lav Dia...
# 36826  Mark L. Lester  ...  Erika Eleniak Adam Baldwin Julie du Page Mark ...
#
# [36827 rows x 7 columns]

# %%
#appending combined dataset of 2018 to old dataset
new_df=old_df.append(new_df18,ignore_index=True)

# %%
new_df
# Out:
#        director_name  ...                                               comb
# 0        Doug Walker  ...  Doug Walker Rob Walker unknown Doug Walker Doc...
# 1      Rob Letterman  ...  Amy Poehler Rainn Wilson Stephen Colbert Rob L...
# 2      George Miller  ...  Robin Williams Brad Pitt Common George Miller ...
# 3            unknown  ...  Don Johnson Philip Michael Thomas John Diehl u...
# 4       Chris Miller  ...  Salma Hayek Constance Marie Amy Sedaris Chris ...
# ...              ...  ...                                                ...
# 37094     Etan Cohen  ...  Will Ferrell John C. Reilly Rebecca Hall Etan ...
# 37095     Adam McKay  ...  Christian Bale Amy Adams Steve Carell Adam McK...
# 37096     Mimi Leder  ...  Felicity Jones Armie Hammer Justin Theroux Mim...
# 37097   Karyn Kusama  ...  Nicole Kidman Sebastian Stan Toby Kebbell Kary...
# 37098    David Slade  ...  Fionn Whitehead Will Poulter Asim Chaudhry Dav...
#
# [37099 rows x 7 columns]

# %%
#checking nan values 
new_df.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           2
# movie_title      0
# comb             2
# dtype: int64

# %%
#removing nan values
new_df=new_df.dropna(how='any')

# %%
#checking nan value
new_df.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# comb             0
# dtype: int64

# %%
#getting new dataset having all 2017 movies
new_df.to_csv('2017_Movie_data.csv',index=False)
